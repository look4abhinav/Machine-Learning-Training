# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("countries.csv")
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         1704 non-null   object
#  1   continent       1704 non-null   object
#  2   year            1704 non-null   int64
#  3   lifeExpectancy  1704 non-null   float64
#  4   population      1704 non-null   int64
#  5   gdpPerCapita    1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data2007 = data[data.year==2007]
data1952 = data[data.year==1952]
data2007.head()
# Out:
#         country continent  year  lifeExpectancy  population  gdpPerCapita
# 11  Afghanistan      Asia  2007          43.828    31889923    974.580338
# 23      Albania    Europe  2007          76.423     3600523   5937.029526
# 35      Algeria    Africa  2007          72.301    33333216   6223.367465
# 47       Angola    Africa  2007          42.731    12420476   4797.231267
# 59    Argentina  Americas  2007          75.320    40301927  12779.379640

# %%
data2007.describe()
# Out:
#          year  lifeExpectancy    population  gdpPerCapita
# count   142.0      142.000000  1.420000e+02    142.000000
# mean   2007.0       67.007423  4.402122e+07  11680.071820
# std       0.0       12.073021  1.476214e+08  12859.937337
# min    2007.0       39.613000  1.995790e+05    277.551859
# 25%    2007.0       57.160250  4.508034e+06   1624.842248
# 50%    2007.0       71.935500  1.051753e+07   6124.371108
# 75%    2007.0       76.413250  3.121004e+07  18008.835640
# max    2007.0       82.603000  1.318683e+09  49357.190170

# %%
data2007.skew()
# Out:
# year              0.000000
# lifeExpectancy   -0.688777
# population        7.400873
# gdpPerCapita      1.224198
# dtype: float64

# %%
temp = data2007.drop('year',axis=1)

# %%
sns.pairplot(temp,diag_kind='kde')

# %%
sns.distplot(data2007['gdpPerCapita'],kde=True)

# %%
sns.distplot(data2007['population'],kde=False)

# %%
sns.distplot(data2007['lifeExpectancy'],kde=False)

# %%
sns.distplot(data1952['lifeExpectancy'],kde=False)

# %%
sns.boxplot(data2007['population'])

# %%
sns.distplot(data2007['lifeExpectancy'])

# %%
sns.boxplot(data2007['lifeExpectancy'])

# %%
sns.boxplot(data1952['lifeExpectancy'])

# %%
sns.distplot(data1952['lifeExpectancy'])

# %%
sns.boxplot(data2007['gdpPerCapita'])

# %%
sns.boxplot(data2007['population'])

# %%
data2007[data2007['gdpPerCapita'] > 41000]
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 863          Kuwait      Asia  2007          77.588     2505559   47306.98978
# 1151         Norway    Europe  2007          80.196     4627926   49357.19017
# 1367      Singapore      Asia  2007          79.972     4553009   47143.17964
# 1619  United States  Americas  2007          78.242   301139947   42951.65309

# %%
sns.distplot(data2007['lifeExpectancy'])
print(data2007['lifeExpectancy'].skew())
# Out:
# -0.6887770648577504

# %%
test = data2007['lifeExpectancy']**4
sns.distplot(test)
print(test.skew())
# Out:
# -0.13857130056162548

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
transformedlife = pd.DataFrame(pt.fit_transform(data2007[['lifeExpectancy']]))
sns.distplot(transformedlife)
print(transformedlife.skew())
# Out:
# 0   -0.294985
# dtype: float64

# %%
sns.boxplot(data2007['lifeExpectancy'])
print(data2007['lifeExpectancy'].skew())
# Out:
# -0.6887770648577501

# %%
import numpy as np
sns.boxplot(np.log10(data2007['lifeExpectancy']))
print(np.log10(data2007['lifeExpectancy']).skew())
# Out:
# -0.9043616686746581

# %%
import numpy as np
sns.boxplot(data2007['lifeExpectancy']**3)

# %%
import numpy as np
sns.distplot(data2007['lifeExpectancy']**4)

# %%
sns.boxplot(data2007['lifeExpectancy']**4)

# %%
sns.boxplot(data2007['lifeExpectancy'])

# %%
sns.boxplot(np.log10(data2007['gdpPerCapita']))

# %%
sns.distplot(data2007['population'])

# %%
sns.distplot(np.log10(data2007['population']))

# %%
sns.boxplot(data2007['population'])

# %%
sns.distplot(np.log10(np.log10(np.log10(data2007['population'])))+1)

# %%
sns.distplot(np.log10(np.log10(np.log10(data2007['population'])))+10)

# %%
import numpy as np
sns.distplot(np.log10(data2007['gdpPerCapita']))

# %%
sns.boxplot(x='year',y='gdpPerCapita',data=data)

# %%
data[(data.year==1952)&(data.gdpPerCapita>40000)]
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 852  Kuwait      Asia  1952          55.565      160000   108382.3529

# %%
data[(data.year==1957)&(data.gdpPerCapita>40000)]
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 853  Kuwait      Asia  1957          58.033      212846   113523.1329

# %%
data[(data.year==1962)&(data.gdpPerCapita>40000)]
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 854  Kuwait      Asia  1962           60.47      358266   95458.11176

# %%
data[(data.year==1967)&(data.gdpPerCapita>40000)]
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 855  Kuwait      Asia  1967          64.624      575003   80894.88326

# %%
sns.boxplot(x='year',y='lifeExpectancy',data=data)

# %%
data[(data.year==1992)&(data.lifeExpectancy<30)]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 1292  Rwanda    Africa  1992          23.599     7290203    737.068595

# %%
sns.boxplot(data2007['population'])
# Out:
# <AxesSubplot:xlabel='population'>

# %%
data2007[data2007.population>200000000]
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 299           China      Asia  2007          72.961  1318683096   4959.114854
# 707           India      Asia  2007          64.698  1110396331   2452.210407
# 719       Indonesia      Asia  2007          70.650   223547000   3540.651564
# 1619  United States  Americas  2007          78.242   301139947  42951.653090

# %%
sns.boxplot(x='year',y='population',data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='population'>

# %%
sns.pairplot(data2007,diag_kind='kde')

# %%
africa2007 = data2007[data2007['continent']=="Africa"]
sns.distplot(africa2007['gdpPerCapita'])

# %%
sns.boxplot(x='gdpPerCapita',y='continent',data=data2007)
# Out:
# <AxesSubplot:xlabel='gdpPerCapita', ylabel='continent'>

# %%
europe2007=data2007[data2007.continent=='Europe']
asia2007=data2007[data2007.continent=='Asia']
sns.distplot(europe2007['gdpPerCapita'])
# Out:
# <AxesSubplot:xlabel='gdpPerCapita', ylabel='Density'>

# %%
sns.distplot(asia2007['gdpPerCapita'])
# Out:
# <AxesSubplot:xlabel='gdpPerCapita', ylabel='Density'>

# %%
sns.boxplot(x='lifeExpectancy',y='continent',data=data2007)
# Out:
# <AxesSubplot:xlabel='lifeExpectancy', ylabel='continent'>

# %%
data2007.head()
data2007 = data2007.drop('year',axis=1)

# %%
data2007.corr()
# Out:
#                 lifeExpectancy  population  gdpPerCapita
# lifeExpectancy        1.000000    0.047553      0.678662
# population            0.047553    1.000000     -0.055676
# gdpPerCapita          0.678662   -0.055676      1.000000

# %%
sns.heatmap(data2007.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data2007,diag_kind='kde')

# %%
data = pd.read_csv("countries.csv")
data2007 = data[data.year==2007]
pt = PowerTransformer(method='box-cox')
data2007 = data2007.drop('country',axis=1)
data2007 = data2007.drop('continent',axis=1)
data2007 = data2007.drop('year',axis=1)
normaldata2007 = pd.DataFrame(pt.fit_transform(data2007))
normaldata2007.columns = data2007.columns
normaldata2007.head()
# Out:
#    lifeExpectancy  population  gdpPerCapita
# 0       -1.646449    0.671593     -1.260438
# 1        0.795705   -0.768959      0.008224
# 2        0.328460    0.699961      0.043439
# 3       -1.686919    0.059195     -0.149736
# 4        0.665390    0.821245      0.595732

# %%
pt.lambdas_
# Out:
# array([ 3.07348028, -0.02689816,  0.06846354])

# %%
sns.pairplot(normaldata2007,diag_kind='kde')

# %%
sns.heatmap(normaldata2007.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
cars = pd.read_csv("car-mpg.csv")
cars.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# 3  16.0    8  304.0  150  3433  12.0  70       1         0
# 4  17.0    8  302.0  140  3449  10.5  70       1         0
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
sns.boxplot(x='origin',y='disp',data = cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='disp'>

# %%
sns.boxplot(x='origin',y='mpg',data = cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
cars = cars.drop('yr',axis=1)
cars = cars.drop('accel',axis=1)

# %%
cars.corr()
# Out:
#              mpg       cyl     displ        hp    weight      size
# mpg     1.000000 -0.777618 -0.805127 -0.778427 -0.832244 -0.777618
# cyl    -0.777618  1.000000  0.950823  0.842983  0.897527  1.000000
# displ  -0.805127  0.950823  1.000000  0.897257  0.932994  0.950823
# hp     -0.778427  0.842983  0.897257  1.000000  0.864538  0.842983
# weight -0.832244  0.897527  0.932994  0.864538  1.000000  0.897527
# size   -0.777618  1.000000  0.950823  0.842983  0.897527  1.000000

# %%
sns.heatmap(cars.corr(),annot=True)

# %%
#Feature Scaling
demo = data2007[['lifeExpectancy','population','gdpPerCapita']]
demo.head()
# Out:
#     lifeExpectancy  population  gdpPerCapita
# 11          43.828    31889923    974.580338
# 23          76.423     3600523   5937.029526
# 35          72.301    33333216   6223.367465
# 47          42.731    12420476   4797.231267
# 59          75.320    40301927  12779.379640

# %%
sns.pairplot(demo,diag_kind='kde')

# %%
sns.pairplot(scaleddemo,diag_kind='kde')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaleddemo = pd.DataFrame(sc.fit_transform(demo))
scaleddemo.columns = demo.columns
scaleddemo.head()
# Out:
#    lifeExpectancy  population  gdpPerCapita
# 0       -1.926732   -0.082469     -0.835415
# 1        0.782646   -0.274783     -0.448165
# 2        0.440015   -0.072658     -0.425820
# 3       -2.017917   -0.214824     -0.537110
# 4        0.690962   -0.025284      0.085786

# %%
scaleddemo
# Out:
#      lifeExpectancy  population  gdpPerCapita
# 0         -1.926732   -0.082469     -0.835415
# 1          0.782646   -0.274783     -0.448165
# 2          0.440015   -0.072658     -0.425820
# 3         -2.017917   -0.214824     -0.537110
# 4          0.690962   -0.025284      0.085786
# ..              ...         ...           ...
# 137        0.601938    0.280360     -0.720936
# 138        0.533196   -0.271942     -0.675381
# 139       -0.358210   -0.148262     -0.733485
# 140       -2.046761   -0.219409     -0.812267
# 141       -1.955077   -0.215567     -0.874813
#
# [142 rows x 3 columns]
