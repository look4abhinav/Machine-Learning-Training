# %% [markdown]
# ### Load tensorflow

# %%
import numpy as np

# %%
import tensorflow as tf
#Train the model
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ### Collect Data

# %%
(trainX, trainY),(testX, testY) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
trainX.shape
# Out:
# (60000, 28, 28)

# %%
trainY.shape
# Out:
# (60000,)

# %% [markdown]
# ### Convert Output label to multiple values

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %%
#rainX=trainX/255
#estX=testX/255    # standardize the data for train and test to be between 0-1

# %% [markdown]
# ## Build the Graph

# %%
tf.keras.backend.clear_session()
#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Reshape data from 2D (28,28) to 3D (28, 28, 1)
model.add(tf.keras.layers.Reshape((28,28,1),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# ### Apply Convolutional Layers, MaxPooling

# %%
model.add(tf.keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# ### Add layers for Classification

# %%
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
#  batch_normalization (BatchN  (None, 28, 28, 1)        4
#  ormalization)
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 10)                40970
#
# =================================================================
# Total params: 428,814
# Trainable params: 428,812
# Non-trainable params: 2
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
model.fit(trainX,trainY,          
          validation_data=(testX,testY),
          epochs=10,
          batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 22s 7ms/step - loss: 0.0935 - accuracy: 0.9721 - val_loss: 0.0390 - val_accuracy: 0.9872
# Epoch 2/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0338 - accuracy: 0.9894 - val_loss: 0.0332 - val_accuracy: 0.9906
# Epoch 3/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0244 - accuracy: 0.9924 - val_loss: 0.0260 - val_accuracy: 0.9921
# Epoch 4/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.0287 - val_accuracy: 0.9928
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0250 - val_accuracy: 0.9936
# Epoch 6/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0282 - val_accuracy: 0.9928
# Epoch 7/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0342 - val_accuracy: 0.9919
# Epoch 8/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0287 - val_accuracy: 0.9928
# Epoch 9/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0259 - val_accuracy: 0.9928
# Epoch 10/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0285 - val_accuracy: 0.9934

# %%
model.save('demo.h5')
