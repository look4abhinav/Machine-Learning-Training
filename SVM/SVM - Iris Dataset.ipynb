# %% [markdown]
# ### Load Data

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = X[:,:2]

# %% [markdown]
# ### Building Model

# %%
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt

# %%
svc = svm.SVC(C=0.01, kernel='linear').fit(X, y)

# %%
def plot_boundary(svc):
    
    # create a mesh to plot in
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    h = (x_max / x_min)/100
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    plt.subplot(1, 1, 1)
    Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.7)

    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    plt.xlim(xx.min(), xx.max())
    #plt.title('SVC with linear kernel')
    plt.show()

# %%
plot_boundary(svc)

# %% [markdown]
# Try different values of C

# %%
svc = svm.SVC(C=1, kernel='linear').fit(X,y)
plot_boundary(svc)

# %% [markdown]
# Using RBF Kernel

# %%
svc = svm.SVC(C=100, kernel='rbf', gamma=100).fit(X,y)
plot_boundary(svc)

# %%
svc = svm.SVC(C=1, kernel='poly', degree=6, gamma=1).fit(X,y)
plot_boundary(svc)
